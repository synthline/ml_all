# %%
import cv2
import matplotlib.pyplot as plt

path = '/media/synthline/mkitt_stora/_codes/iaml_autumn22/w35/img112.jpg'
img = cv2.imread(path)

cvt = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(cvt)

# %%
cvt2 = cv2.cvtColor(cvt, cv2.COLOR_RGB2GRAY)
plt.imshow(cvt2)
